# %% [markdown]
# # Лабораторная работа №1
#
# ФИО:  **указать**
# Группа: **указать**
#
# Отправлять можно следующими способами (**обязательно указать свое ФИО и группу в каком-либо виде**):
# 1. Создать **приватный** репозиторий на github, добавить меня по нику (l3lush) в Collaborators (Settings -> Collaborators -> Add people)
# 2. Отправить заполненный ноутбук мне на почту avmysh@gmail.com, либо m1603956@edu.misis.ru
# 3. Отправить заполненный ноутбук мне в тг @l3lush.
#
# **Deadlines**:
# - soft -- **02.04.2023 23:59** (за сдачу в пределах этого времени +1 балл в табличку)
# - hard -- **начало зачетной недели (ориентировочно июнь 2023)**
#
#
# **Исходные данные**:
# + Датасет, согласно варианту (смотрим [тут](https://docs.google.com/spreadsheets/d/1TM4EqGhCHA9B35SuIcBqorSI3u4mxs2V02Ujth-eSI4/edit?usp=sharing))
#
# **Что необходимо сделать** (по каждому заданию должна быть приведена хотя бы одна ячейка кода, либо текст, как-то поясняющий ее отсутствие):
# 1. Вывести первые 5 рядов датасета.
# 2. Посмотреть количество уникальных элементов в целевой переменной, и посчитать, какое количество наблюдений каждого класса.
# 3. Вывести основные статистики по датасету.
# 4. Вывести основную информацию по датасету.
# 5. Проверить данные на наличие миссингов (NaN).
# 6. \*Если есть NaNы, заполнить их по следующей стратегии:
# + Если переменнная непрерывная, то медианным значением.
# + Если категориальная перемернная, заполнить модой.
# 7. Отобразить зависимость целевой переменной по другой любой переменной.
# 8. Посчитать корреляции между признаками (можжно не по всем, если численных переменнных слишком много).
# 9. Посчитать среднее значение целевой переменной по какому-либо категориальному признаку, если такие есть.
# 10. Нарисовать гистограмму какого-либо признака.

# %% [markdown]
# # 0. Пример импорта данных

# %%
import warnings
warnings.filterwarnings("ignore")


from sklearn.datasets import fetch_openml
name_of_dataset = "credit-g"  # название вашего датасета из таблицы
data = fetch_openml(name=name_of_dataset)

# %%
data.data  # непорсредственно данные
# Out:
#     checking_status  duration                  credit_history  \
# 0                <0       6.0  critical/other existing credit
# 1          0<=X<200      48.0                   existing paid
# 2       no checking      12.0  critical/other existing credit
# 3                <0      42.0                   existing paid
# 4                <0      24.0              delayed previously
# ..              ...       ...                             ...
# 995     no checking      12.0                   existing paid
# 996              <0      30.0                   existing paid
# 997     no checking      12.0                   existing paid
# 998              <0      45.0                   existing paid
# 999        0<=X<200      45.0  critical/other existing credit
#
#                  purpose  credit_amount    savings_status  employment  \
# 0               radio/tv         1169.0  no known savings         >=7
# 1               radio/tv         5951.0              <100      1<=X<4
# ...

# %%
data.target  # целевая переменная

# %%
print(data.DESCR)  # описание датасета

# %% [markdown]
# # 1. Ваше решение
